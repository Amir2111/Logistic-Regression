# %%
import pandas as pd
dataset = pd.read_csv("/content/sample_data/heart(1).csv")

X_features_input = dataset.iloc[:, :-1].values


Y_label_output = dataset.iloc[:, 8].values
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_features_input, Y_label_output, test_size = 20, random_state = 4)

from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
parameter = {
    'kernel':('linear', 'rbf', 'poly')
    ,'C': [1, 10]   
}
clf = SVC()
new = GridSearchCV(clf, parameter)
new.fit(X_train,Y_train)
new.get_params
# Out:
# <bound method BaseEstimator.get_params of GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [1, 10], 'kernel': ('linear', 'rbf', 'poly')},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)>
